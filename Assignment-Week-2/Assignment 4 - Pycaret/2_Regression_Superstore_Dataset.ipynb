# %% [markdown]
# # 2. Regression Using Pycaret.

# %% [markdown]
# # Installation
#
# Install the Pycaret libarary.

# %%
# !pip install pycaret

# %% [markdown]
# # Setup
#
#
# *   Mount drive and load the dataset the dataset using Pandas library.
# *   Dataset used for analysis is Kaggle's Superstore dataset - https://www.kaggle.com/datasets/ishanshrivastava28/superstore-sales

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Load dataset from google drive
import pandas as pd
url = "/content/drive/MyDrive/DM-Assignment-Dataset/Superstore.csv"
df = pd.read_csv(url,encoding='windows-1252',error_bad_lines = False)
# Out:
# <ipython-input-3-6a9aa06a4f04>:4: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(url,encoding='windows-1252',error_bad_lines = False)

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %% [markdown]
# # Model Building

# %%
from pycaret.regression import *
reg_setup = setup(df, target='Profit',use_gpu= True)
# Out:
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 2, number of used features: 0
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Warning] Using sparse features with CUDA is currently not supported.
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 0
# ...

# %%
# compare models and return the best model
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_48536 th {
#   text-align: left;
# }
# ...

# %%
best_model
# Out:
# GradientBoostingRegressor(random_state=8984)

# %% [markdown]
# # Analysis

# %%
from pycaret.regression import evaluate_model
evaluate_model(best_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# # Test Model

# %%
# Prediction on Test Set
prediction = predict_model(best_model)
# Out:
# <style type="text/css">
# </style>
# <table id="T_0cd9e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0cd9e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_0cd9e_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_0cd9e_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_0cd9e_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_0cd9e_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_0cd9e_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_0cd9e_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0cd9e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0cd9e_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_0cd9e_row0_col1" class="data row0 col1" >43.8026</td>
# ...

# %%
prediction.head()
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 582      583  CA-2014-145233  02-12-2014  06-12-2014  Standard Class
# 5696    5697  CA-2014-126123  15-10-2014  19-10-2014  Standard Class
# 6272    6273  CA-2014-149706  12-12-2014  13-12-2014     First Class
# 2021    2022  CA-2013-168354  20-09-2013  22-09-2013     First Class
# 6881    6882  CA-2012-137113  01-12-2012  05-12-2012    Second Class
#
#      Customer ID      Customer Name      Segment        Country        City  \
# 582     DV-13465   Dianna Vittorini     Consumer  United States      Denver
# 5696    AG-10765  Anthony Garverick  Home Office  United States     Chicago
# 6272    AS-10285   Alejandro Savely    Corporate  United States    Palatine
# 2021    RH-19510     Rick Huthwaite  Home Office  United States  Providence
# 6881    TW-21025  Tamara Willingham  Home Office  United States     Seattle
#
#       ...   Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# # Save The Model

# %%
from pycaret.regression import finalize_model, save_model
final_et = finalize_model(best_model)
save_model(final_et, 'final_et_model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['Row ID', 'Postal Code', 'Sales',
#                                               'Quantity', 'Discount'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=['Order ID', 'Order Date',
#                                               'Ship Date', 'Ship Mode',
#                                               'Customer ID', 'Customer Name',
#                                               'Segment', 'Country', 'City',
#                                               'State', 'Region', 'Produc...
#                                               'Customer Name', 'City', 'State',
#                                               'Product ID', 'Product Name'],
# ...

# %% [markdown]
# # Load The Saved Model

# %%
# load pipeline
from pycaret.regression import load_model
loaded_best_pipeline = load_model('final_et_model')
loaded_best_pipeline
# Out:
# Transformation Pipeline and Model Successfully Loaded
# Pipeline(memory=FastMemory(location=/tmp/joblib),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(include=['Row ID', 'Postal Code', 'Sales',
#                                              'Quantity', 'Discount'],
#                                     transformer=SimpleImputer())),
#                 ('categorical_imputer',
#                  TransformerWrapper(include=['Order ID', 'Order Date',
#                                              'Ship Date', 'Ship Mode',
#                                              'Customer ID', 'Customer Name',
#                                              'Segment', 'Country', 'City',
#                                              'State', 'Regi...
#                                              'Customer Name', 'City', 'State',
#                                              'Product ID', 'Product Name'],
# ...

# %% [markdown]
# # Create UI Using Gradio

# %%
# !pip install gradio
# !pip install pycaret[mlops]
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.1/20.1 MB 46.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.2/66.2 kB 8.2 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.2/298.2 kB 33.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.4/75.4 kB 9.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 30.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 3.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 15.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 8.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.5/74.5 kB 9.1 MB/s eta 0:00:00
# ...

# %%
create_app(loaded_best_pipeline)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Note: opening Chrome Inspector may crash demo inside Colab notebooks.
#
# To create a public link, set `share=True` in `launch()`.
